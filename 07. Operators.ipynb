# %% [markdown]
# # Operators
# Special symbols that perform arithmetic or logical computations

# %% [markdown]
# # Operators Type
# 1. Arithmetic
# 2. Assignment
# 3. Comparison / Relational
# 4. Logical/ Boolean
# 5. Membership
# 6. Identity

# %% [markdown]
# ## Arithmetic
# Addition, Subtraction, Multiplication, Division, Floor Division, Modulo, Exponents and parenthesis
# +,_,*,/,//,%,**,()

# %%
x,u = 10,20

# %%
print(x)
print(u)
# Out:
# 10
# 20

# %% [markdown]
# ### Addition

# %%
print(3+4)
# Out:
# 7

# %%
8+34
# Out:
# 42

# %% [markdown]
# ### Subtraction

# %%
45-23
# Out:
# 22

# %%
5-6
# Out:
# -1

# %% [markdown]
# ### Multiplication

# %%
342*34
# Out:
# 11628

# %% [markdown]
# ### Division

# %%
6/3
#divison values are always given as float
# Out:
# 2.0

# %%
16/5
# Out:
# 3.2

# %%
23/7
# Out:
# 3.2857142857142856

# %% [markdown]
# ### Floor Division

# %%
16//3
#no decimal values
# Out:
# 5

# %%
23//7
# Out:
# 3

# %% [markdown]
# ### Modulo Remainder

# %%
16%5
# Out:
# 1

# %%
23%7
# Out:
# 2

# %% [markdown]
# ### Power/Exponent

# %%
10**2
# Out:
# 100

# %%
9**8
# Out:
# 43046721

# %% [markdown]
# ### Parenthesis

# %%
(2+3)*(5+4)
# Out:
# 45

# %% [markdown]
# ### Arithmetic operators precedence
#
# 1. Parenthesis
# 2. Exponents
# 3. Floor Division
# 4. Division or Multiplication
# 5. Modulus
# 6. Addition or Subtraction

# %%
5*5+5/5-5
# Out:
# 21.0

# %%
## Whenever we use boolean values in operators they will automatically be converted to int

# %%
True+True
# Out:
# 2

# %%
b=2.3
c=True
d=False
b+c+d
# Out:
# 3.3

# %%
m=8
n=False
m/n
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /var/folders/fh/8wlf5_bd2hg7ys59grg30w180000gn/T/ipykernel_13435/98889205.py in <module>
#       1 m=8
#       2 n=False
# ----> 3 m/n
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # Assignment Operator

# %% [markdown]
# ### Assignment operators are used in python to assign values to variables
# ### (=,+=,-+,*=,/=,//=,%=)
# ### First right side will be executed first and then the left side

# %%
a=10
a
# Out:
# 10

# %%
id(a)
# Out:
# 4383417848

# %%
a=a+5
a
# Out:
# 20

# %%
id(a)
# Out:
# 140387582929648

# %%
a+=1
a
# Out:
# 21

# %%
a-=5
a
#a=a-5
# Out:
# 11

# %% [markdown]
#  # Comparision/Realtional Operators
#     Comparision operators are used to compare values. It returns either true or false according to the condition
#     <,>,==,!=,<=,>=

# %%
45>35
# Out:
# True

# %%
45<35
# Out:
# False

# %%
3*3<3*6
# Out:
# True

# %%
45=45
# Numericals cannot be assigned values
# Out:
#   File "/var/folders/fh/8wlf5_bd2hg7ys59grg30w180000gn/T/ipykernel_13435/1243245874.py", line 1
#     45=45
#     ^
# SyntaxError: cannot assign to literal

# %%
# != is not equal to
3!=5
# Out:
# True

# %%
1<=2
# Out:
# True

# %%
2>=1
# Out:
# True

# %%
45=45.0
# Out:
#   File "/var/folders/fh/8wlf5_bd2hg7ys59grg30w180000gn/T/ipykernel_13435/1328438087.py", line 1
#     45=45.0
#     ^
# SyntaxError: cannot assign to literal

# %%
'hi'='HI'
# python is case sensitive
# Out:
#   File "/var/folders/fh/8wlf5_bd2hg7ys59grg30w180000gn/T/ipykernel_13435/59689582.py", line 1
#     'hi'='HI'
#     ^
# SyntaxError: cannot assign to literal

# %%
x = 5
y = 5
z = 10

print(x == y)   # True, because 5 equals 5
print(x == z)   # False, because 5 does not equal 10

# %% [markdown]
# == sign is used to compare values whereas = is used to assign values

# %% [markdown]
# # Logical Operators
# ### It returns bool types only
# ### Logical operators are and, or, not opeerators
# ### when we have OR operator atleast one condition should be true and then overall value will be TRUE
# ### when we have AND operator all conditions should be true and then overall value will be TRUE

# %% [markdown]
# ![Screenshot%202025-08-27%20at%206.26.21%E2%80%AFPM.png](attachment:Screenshot%202025-08-27%20at%206.26.21%E2%80%AFPM.png)

# %% [markdown]
# #### or

# %%
complex(10)
# Out:
# (10+0j)

# %%
(1<2)or(1>2)
# Out:
# True

# %%
(3<2)or(1>2)
# Out:
# False

# %% [markdown]
# #### and

# %%
(1<2)and(1>2)
# Out:
# False

# %%
(1<2)or(2>3)
# Out:
# True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# Logical Operators pecedence
# Logial NOT
# Logical AND
# Logical OR

# %%
(2==2) or (3==3) and(3==4)
# Explanation
# True or True and False
# and should be given priority first so
# True or (True and False)
# true or false
#false
# Out:
# True

# %% [markdown]
# ## Identity Operators

# %%
a=5
b=5
print(a is b)
# Out:
# True

# %%
l=0
j=9
print(l is j)
# Out:
# False

# %%
p=0
q=9
p is not q
# Out:
# True

# %%
k=5
m=5
p is not q
# Out:
# True

# %%
a='Ayesha'
'sha' in a
# Out:
# True

# %%
'sha' not in a
# Out:
# True

# %% [markdown]
# ### Urinary operator
# #### only one operator

# %%
n = 4

# %%
m = -(n)
m
# Out:
# -4

# %%
-n
# Out:
# -4
